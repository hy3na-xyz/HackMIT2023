# %%
import pandas as pd 
import numpy as np 
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import categorical_crossentropy

import random
import numpy as np

import mne
from mne import io
from mne.datasets import sample

# EEGNet-specific imports
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# PyRiemann imports
from pyriemann.estimation import XdawnCovariances
from pyriemann.tangentspace import TangentSpace
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt

from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras import backend as K

# %%
df = pd.read_pickle('/Users/akhil/Downloads/HackMIT2023/1.pkl')

# %%
from pathlib import Path

# Create a Path object
path_obj = Path("/Users/akhil/Downloads/HackMIT2023/mlmodel")

# Convert the Path object to a string
path_str = str(path_obj)

# Now you can concatenate it with a string
result = path_str + "test.txt"

print(result)
# Out:
# /Users/akhil/Downloads/HackMIT2023/mlmodeltest.txt

# %%
from pathlib import Path

# Create a Path object for the data_path
data_path = Path(sample.data_path())

# Set parameters and read data
raw_fname = str(data_path / 'MEG/sample/sample_audvis_filt-0-40_raw.fif')
event_fname = str(data_path / 'MEG/sample/sample_audvis_filt-0-40_raw-eve.fif')
tmin, tmax = -0., 1

# Rest of your code...

# %%
def EEGNet(nb_classes, Chans = 64, Samples = 128, 
             dropoutRate = 0.5, kernLength = 64, F1 = 8, 
             D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout'):
    """
   
    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer. We found
                        that setting this to be half the sampling rate worked
                        well in practice. For the SMR dataset in particular
                        since the data was high-passed at 4Hz we used a kernel
                        length of 32.     
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. Default: F1 = 8, F2 = F1 * D. 
      D               : number of spatial filters to learn within each temporal
                        convolution. Default: D = 2
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.

    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense', 
                         kernel_constraint = max_norm(norm_rate))(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)

# while the default tensorflow ordering is 'channels_last' we set it here
# to be explicit in case if the user has changed the default ordering
K.set_image_data_format('channels_last')

##################### Process, filter and epoch the data ######################
data_path = sample.data_path()

# Set parameters and read data
tmin, tmax = -0., 1
event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)

# Setup for reading the raw data
raw = io.Raw(raw_fname, preload=True, verbose=False)
raw.filter(2, None, method='iir')  # replace baselining with high-pass
events = mne.read_events(event_fname)

raw.info['bads'] = ['MEG 2443']  # set bad channels
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                       exclude='bads')

# Read epochs
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=False,
                    picks=picks, baseline=None, preload=True, verbose=False)
labels = epochs.events[:, -1]

# extract raw data. scale by 1000 due to scaling sensitivity in deep learning
X = epochs.get_data()*1000 # format is in (trials, channels, samples)
y = labels

kernels, chans, samples = 1, 60, 151

# take 50/25/25 percent of the data to train/validate/test
X_train      = X[0:144,]
Y_train      = y[0:144]
X_validate   = X[144:216,]
Y_validate   = y[144:216]
X_test       = X[216:,]
Y_test       = y[216:]

############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train-1)
Y_validate   = np_utils.to_categorical(Y_validate-1)
Y_test       = np_utils.to_categorical(Y_test-1)

# convert data to NHWC (trials, channels, samples, kernels) format. Data 
# contains 60 channels and 151 time-points. Set the number of kernels to 1.
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)
   
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
model = EEGNet(nb_classes = 4, Chans = chans, Samples = samples, 
               dropoutRate = 0.5, kernLength = 32, F1 = 8, D = 2, F2 = 16, 
               dropoutType = 'Dropout')

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='/tmp/checkpoint.h5', verbose=1,
                               save_best_only=True)

###############################################################################
# if the classification task was imbalanced (significantly more trials in one
# class versus the others) you can assign a weight to each class during 
# optimization to balance it out. This data is approximately balanced so we 
# don't need to do this, but is shown here for illustration/completeness. 
###############################################################################

# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1, 2:1, 3:1}

################################################################################
# fit the model. Due to very small sample sizes this can get
# pretty noisy run-to-run, but most runs should be comparable to xDAWN + 
# Riemannian geometry classification (below)
################################################################################
fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 300, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer], class_weight = class_weights)

# load optimal weights
model.load_weights('/tmp/checkpoint.h5')

###############################################################################
# can alternatively used the weights provided in the repo. If so it should get
# you 93% accuracy. Change the WEIGHTS_PATH variable to wherever it is on your
# system.
###############################################################################

# WEIGHTS_PATH = /path/to/EEGNet-8-2-weights.h5 
# model.load_weights(WEIGHTS_PATH)

###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))


############################# PyRiemann Portion ##############################

# code is taken from PyRiemann's ERP sample script, which is decoding in 
# the tangent space with a logistic regression

n_components = 2  # pick some components

# set up sklearn pipeline
clf = make_pipeline(XdawnCovariances(n_components),
                    TangentSpace(metric='riemann'),
                    LogisticRegression())

preds_rg     = np.zeros(len(Y_test))

# reshape back to (trials, channels, samples)
X_train      = X_train.reshape(X_train.shape[0], chans, samples)
X_test       = X_test.reshape(X_test.shape[0], chans, samples)

# train a classifier with xDAWN spatial filtering + Riemannian Geometry (RG)
# labels need to be back in single-column format
clf.fit(X_train, Y_train.argmax(axis = -1))
preds_rg     = clf.predict(X_test)

# Printing the results
acc2         = np.mean(preds_rg == Y_test.argmax(axis = -1))
print("Classification accuracy: %f " % (acc2))
print(random.choice([0, 1]))
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB
#
# X_train shape: (144, 60, 151, 1)
# 144 train samples
# 72 test samples
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 1.38633, saving model to /tmp/checkpoint.h5
# 9/9 - 1s - loss: 1.3672 - accuracy: 0.2778 - val_loss: 1.3863 - val_accuracy: 0.2361 - 649ms/epoch - 72ms/step
# Epoch 2/300
#
# Epoch 2: val_loss improved from 1.38633 to 1.38631, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.3819 - accuracy: 0.2292 - val_loss: 1.3863 - val_accuracy: 0.2361 - 203ms/epoch - 23ms/step
# Epoch 3/300
#
# Epoch 3: val_loss did not improve from 1.38631
# 9/9 - 0s - loss: 1.3726 - accuracy: 0.3611 - val_loss: 1.3863 - val_accuracy: 0.2361 - 197ms/epoch - 22ms/step
# Epoch 4/300
#
# Epoch 4: val_loss did not improve from 1.38631
# 9/9 - 0s - loss: 1.3796 - accuracy: 0.2708 - val_loss: 1.3864 - val_accuracy: 0.2361 - 190ms/epoch - 21ms/step
# Epoch 5/300
#
# Epoch 5: val_loss did not improve from 1.38631
# 9/9 - 0s - loss: 1.3616 - accuracy: 0.3819 - val_loss: 1.3864 - val_accuracy: 0.2361 - 193ms/epoch - 21ms/step
# Epoch 6/300
#
# Epoch 6: val_loss did not improve from 1.38631
# 9/9 - 0s - loss: 1.3603 - accuracy: 0.3750 - val_loss: 1.3864 - val_accuracy: 0.2361 - 191ms/epoch - 21ms/step
# Epoch 7/300
#
# Epoch 7: val_loss did not improve from 1.38631
# 9/9 - 0s - loss: 1.3492 - accuracy: 0.3958 - val_loss: 1.3864 - val_accuracy: 0.2361 - 190ms/epoch - 21ms/step
# Epoch 8/300
#
# Epoch 8: val_loss did not improve from 1.38631
# 9/9 - 0s - loss: 1.3384 - accuracy: 0.4097 - val_loss: 1.3864 - val_accuracy: 0.2361 - 194ms/epoch - 22ms/step
# Epoch 9/300
#
# Epoch 9: val_loss did not improve from 1.38631
# 9/9 - 0s - loss: 1.3485 - accuracy: 0.3681 - val_loss: 1.3864 - val_accuracy: 0.2361 - 190ms/epoch - 21ms/step
# Epoch 10/300
#
# Epoch 10: val_loss did not improve from 1.38631
# 9/9 - 0s - loss: 1.3323 - accuracy: 0.4097 - val_loss: 1.3864 - val_accuracy: 0.2361 - 187ms/epoch - 21ms/step
# Epoch 11/300
#
# Epoch 11: val_loss did not improve from 1.38631
# 9/9 - 0s - loss: 1.3384 - accuracy: 0.3472 - val_loss: 1.3864 - val_accuracy: 0.2361 - 188ms/epoch - 21ms/step
# Epoch 12/300
#
# Epoch 12: val_loss improved from 1.38631 to 1.38626, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.2972 - accuracy: 0.5000 - val_loss: 1.3863 - val_accuracy: 0.2361 - 210ms/epoch - 23ms/step
# Epoch 13/300
#
# Epoch 13: val_loss improved from 1.38626 to 1.38616, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.2938 - accuracy: 0.4722 - val_loss: 1.3862 - val_accuracy: 0.2361 - 218ms/epoch - 24ms/step
# Epoch 14/300
#
# Epoch 14: val_loss improved from 1.38616 to 1.38593, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.2897 - accuracy: 0.4236 - val_loss: 1.3859 - val_accuracy: 0.2361 - 206ms/epoch - 23ms/step
# Epoch 15/300
#
# Epoch 15: val_loss improved from 1.38593 to 1.38565, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.2627 - accuracy: 0.4931 - val_loss: 1.3857 - val_accuracy: 0.2361 - 204ms/epoch - 23ms/step
# Epoch 16/300
#
# Epoch 16: val_loss improved from 1.38565 to 1.38528, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.2292 - accuracy: 0.5486 - val_loss: 1.3853 - val_accuracy: 0.4028 - 206ms/epoch - 23ms/step
# Epoch 17/300
#
# Epoch 17: val_loss improved from 1.38528 to 1.38482, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.2205 - accuracy: 0.5069 - val_loss: 1.3848 - val_accuracy: 0.3750 - 206ms/epoch - 23ms/step
# Epoch 18/300
#
# Epoch 18: val_loss improved from 1.38482 to 1.38428, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.1959 - accuracy: 0.5000 - val_loss: 1.3843 - val_accuracy: 0.3056 - 204ms/epoch - 23ms/step
# Epoch 19/300
#
# Epoch 19: val_loss improved from 1.38428 to 1.38353, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.1681 - accuracy: 0.5347 - val_loss: 1.3835 - val_accuracy: 0.2917 - 203ms/epoch - 23ms/step
# Epoch 20/300
#
# Epoch 20: val_loss improved from 1.38353 to 1.38249, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.1514 - accuracy: 0.4931 - val_loss: 1.3825 - val_accuracy: 0.3611 - 204ms/epoch - 23ms/step
# Epoch 21/300
#
# Epoch 21: val_loss improved from 1.38249 to 1.38131, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.1293 - accuracy: 0.5417 - val_loss: 1.3813 - val_accuracy: 0.3611 - 208ms/epoch - 23ms/step
# Epoch 22/300
#
# Epoch 22: val_loss improved from 1.38131 to 1.38024, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.1041 - accuracy: 0.5556 - val_loss: 1.3802 - val_accuracy: 0.2917 - 205ms/epoch - 23ms/step
# Epoch 23/300
#
# Epoch 23: val_loss improved from 1.38024 to 1.37888, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0713 - accuracy: 0.5486 - val_loss: 1.3789 - val_accuracy: 0.3333 - 205ms/epoch - 23ms/step
# Epoch 24/300
#
# Epoch 24: val_loss improved from 1.37888 to 1.37743, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0570 - accuracy: 0.5208 - val_loss: 1.3774 - val_accuracy: 0.4167 - 199ms/epoch - 22ms/step
# Epoch 25/300
#
# Epoch 25: val_loss improved from 1.37743 to 1.37586, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0267 - accuracy: 0.6042 - val_loss: 1.3759 - val_accuracy: 0.3750 - 204ms/epoch - 23ms/step
# Epoch 26/300
#
# Epoch 26: val_loss improved from 1.37586 to 1.37365, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0397 - accuracy: 0.5556 - val_loss: 1.3737 - val_accuracy: 0.3611 - 202ms/epoch - 22ms/step
# Epoch 27/300
#
# Epoch 27: val_loss improved from 1.37365 to 1.37148, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0022 - accuracy: 0.6111 - val_loss: 1.3715 - val_accuracy: 0.4028 - 210ms/epoch - 23ms/step
# Epoch 28/300
#
# Epoch 28: val_loss improved from 1.37148 to 1.36914, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0201 - accuracy: 0.5208 - val_loss: 1.3691 - val_accuracy: 0.4028 - 201ms/epoch - 22ms/step
# Epoch 29/300
#
# Epoch 29: val_loss improved from 1.36914 to 1.36655, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0099 - accuracy: 0.5694 - val_loss: 1.3665 - val_accuracy: 0.4167 - 205ms/epoch - 23ms/step
# Epoch 30/300
#
# Epoch 30: val_loss improved from 1.36655 to 1.36394, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9837 - accuracy: 0.5556 - val_loss: 1.3639 - val_accuracy: 0.3611 - 203ms/epoch - 23ms/step
# Epoch 31/300
#
# Epoch 31: val_loss improved from 1.36394 to 1.36094, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9725 - accuracy: 0.6042 - val_loss: 1.3609 - val_accuracy: 0.4028 - 206ms/epoch - 23ms/step
# Epoch 32/300
#
# Epoch 32: val_loss improved from 1.36094 to 1.35931, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 1.0070 - accuracy: 0.5139 - val_loss: 1.3593 - val_accuracy: 0.4167 - 202ms/epoch - 22ms/step
# Epoch 33/300
#
# Epoch 33: val_loss improved from 1.35931 to 1.35602, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9602 - accuracy: 0.5625 - val_loss: 1.3560 - val_accuracy: 0.3611 - 201ms/epoch - 22ms/step
# Epoch 34/300
#
# Epoch 34: val_loss improved from 1.35602 to 1.35317, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9854 - accuracy: 0.5625 - val_loss: 1.3532 - val_accuracy: 0.4028 - 205ms/epoch - 23ms/step
# Epoch 35/300
#
# Epoch 35: val_loss improved from 1.35317 to 1.34845, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9586 - accuracy: 0.5972 - val_loss: 1.3484 - val_accuracy: 0.4167 - 204ms/epoch - 23ms/step
# Epoch 36/300
#
# Epoch 36: val_loss improved from 1.34845 to 1.34413, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9536 - accuracy: 0.6111 - val_loss: 1.3441 - val_accuracy: 0.3750 - 203ms/epoch - 23ms/step
# Epoch 37/300
#
# Epoch 37: val_loss improved from 1.34413 to 1.34282, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9518 - accuracy: 0.5556 - val_loss: 1.3428 - val_accuracy: 0.4028 - 202ms/epoch - 22ms/step
# Epoch 38/300
#
# Epoch 38: val_loss improved from 1.34282 to 1.33729, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9749 - accuracy: 0.5347 - val_loss: 1.3373 - val_accuracy: 0.3889 - 203ms/epoch - 23ms/step
# Epoch 39/300
#
# Epoch 39: val_loss improved from 1.33729 to 1.33171, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9561 - accuracy: 0.5278 - val_loss: 1.3317 - val_accuracy: 0.3889 - 203ms/epoch - 23ms/step
# Epoch 40/300
#
# Epoch 40: val_loss improved from 1.33171 to 1.32924, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9320 - accuracy: 0.5903 - val_loss: 1.3292 - val_accuracy: 0.4167 - 201ms/epoch - 22ms/step
# Epoch 41/300
#
# Epoch 41: val_loss improved from 1.32924 to 1.32254, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9663 - accuracy: 0.5139 - val_loss: 1.3225 - val_accuracy: 0.3750 - 222ms/epoch - 25ms/step
# Epoch 42/300
#
# Epoch 42: val_loss improved from 1.32254 to 1.31822, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9622 - accuracy: 0.5556 - val_loss: 1.3182 - val_accuracy: 0.3889 - 217ms/epoch - 24ms/step
# Epoch 43/300
#
# Epoch 43: val_loss improved from 1.31822 to 1.30849, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9086 - accuracy: 0.6528 - val_loss: 1.3085 - val_accuracy: 0.3889 - 209ms/epoch - 23ms/step
# Epoch 44/300
#
# Epoch 44: val_loss improved from 1.30849 to 1.30330, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8966 - accuracy: 0.6181 - val_loss: 1.3033 - val_accuracy: 0.4167 - 208ms/epoch - 23ms/step
# Epoch 45/300
#
# Epoch 45: val_loss improved from 1.30330 to 1.30022, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9207 - accuracy: 0.6319 - val_loss: 1.3002 - val_accuracy: 0.4028 - 204ms/epoch - 23ms/step
# Epoch 46/300
#
# Epoch 46: val_loss improved from 1.30022 to 1.28855, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9272 - accuracy: 0.6250 - val_loss: 1.2885 - val_accuracy: 0.3889 - 201ms/epoch - 22ms/step
# Epoch 47/300
#
# Epoch 47: val_loss improved from 1.28855 to 1.28486, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9358 - accuracy: 0.5278 - val_loss: 1.2849 - val_accuracy: 0.4306 - 201ms/epoch - 22ms/step
# Epoch 48/300
#
# Epoch 48: val_loss improved from 1.28486 to 1.28236, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9098 - accuracy: 0.6389 - val_loss: 1.2824 - val_accuracy: 0.4028 - 215ms/epoch - 24ms/step
# Epoch 49/300
#
# Epoch 49: val_loss improved from 1.28236 to 1.27017, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9072 - accuracy: 0.6458 - val_loss: 1.2702 - val_accuracy: 0.4167 - 211ms/epoch - 23ms/step
# Epoch 50/300
#
# Epoch 50: val_loss improved from 1.27017 to 1.26712, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9117 - accuracy: 0.6042 - val_loss: 1.2671 - val_accuracy: 0.4306 - 205ms/epoch - 23ms/step
# Epoch 51/300
#
# Epoch 51: val_loss improved from 1.26712 to 1.25167, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8699 - accuracy: 0.6389 - val_loss: 1.2517 - val_accuracy: 0.4444 - 209ms/epoch - 23ms/step
# Epoch 52/300
#
# Epoch 52: val_loss did not improve from 1.25167
# 9/9 - 0s - loss: 0.8890 - accuracy: 0.5625 - val_loss: 1.2524 - val_accuracy: 0.3889 - 190ms/epoch - 21ms/step
# Epoch 53/300
#
# Epoch 53: val_loss improved from 1.25167 to 1.23875, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.9037 - accuracy: 0.6111 - val_loss: 1.2387 - val_accuracy: 0.4306 - 209ms/epoch - 23ms/step
# Epoch 54/300
#
# Epoch 54: val_loss improved from 1.23875 to 1.22760, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8736 - accuracy: 0.6181 - val_loss: 1.2276 - val_accuracy: 0.4306 - 209ms/epoch - 23ms/step
# Epoch 55/300
#
# Epoch 55: val_loss did not improve from 1.22760
# 9/9 - 0s - loss: 0.8653 - accuracy: 0.6111 - val_loss: 1.2284 - val_accuracy: 0.3889 - 191ms/epoch - 21ms/step
# Epoch 56/300
#
# Epoch 56: val_loss improved from 1.22760 to 1.20640, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8772 - accuracy: 0.6389 - val_loss: 1.2064 - val_accuracy: 0.4444 - 202ms/epoch - 22ms/step
# Epoch 57/300
#
# Epoch 57: val_loss did not improve from 1.20640
# 9/9 - 0s - loss: 0.8722 - accuracy: 0.6181 - val_loss: 1.2088 - val_accuracy: 0.3889 - 191ms/epoch - 21ms/step
# Epoch 58/300
#
# Epoch 58: val_loss improved from 1.20640 to 1.20402, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8965 - accuracy: 0.5972 - val_loss: 1.2040 - val_accuracy: 0.4306 - 205ms/epoch - 23ms/step
# Epoch 59/300
#
# Epoch 59: val_loss improved from 1.20402 to 1.16775, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8793 - accuracy: 0.6597 - val_loss: 1.1677 - val_accuracy: 0.4306 - 205ms/epoch - 23ms/step
# Epoch 60/300
#
# Epoch 60: val_loss improved from 1.16775 to 1.16565, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8613 - accuracy: 0.6667 - val_loss: 1.1657 - val_accuracy: 0.4583 - 199ms/epoch - 22ms/step
# Epoch 61/300
#
# Epoch 61: val_loss improved from 1.16565 to 1.15977, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8632 - accuracy: 0.6319 - val_loss: 1.1598 - val_accuracy: 0.3889 - 206ms/epoch - 23ms/step
# Epoch 62/300
#
# Epoch 62: val_loss improved from 1.15977 to 1.14472, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8670 - accuracy: 0.6597 - val_loss: 1.1447 - val_accuracy: 0.4583 - 201ms/epoch - 22ms/step
# Epoch 63/300
#
# Epoch 63: val_loss did not improve from 1.14472
# 9/9 - 0s - loss: 0.8395 - accuracy: 0.6458 - val_loss: 1.1529 - val_accuracy: 0.4167 - 187ms/epoch - 21ms/step
# Epoch 64/300
#
# Epoch 64: val_loss improved from 1.14472 to 1.13030, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8467 - accuracy: 0.6806 - val_loss: 1.1303 - val_accuracy: 0.5000 - 201ms/epoch - 22ms/step
# Epoch 65/300
#
# Epoch 65: val_loss improved from 1.13030 to 1.12116, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8601 - accuracy: 0.6181 - val_loss: 1.1212 - val_accuracy: 0.4583 - 198ms/epoch - 22ms/step
# Epoch 66/300
#
# Epoch 66: val_loss improved from 1.12116 to 1.10435, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8123 - accuracy: 0.7083 - val_loss: 1.1044 - val_accuracy: 0.5278 - 206ms/epoch - 23ms/step
# Epoch 67/300
#
# Epoch 67: val_loss did not improve from 1.10435
# 9/9 - 0s - loss: 0.8430 - accuracy: 0.6736 - val_loss: 1.1087 - val_accuracy: 0.4583 - 208ms/epoch - 23ms/step
# Epoch 68/300
#
# Epoch 68: val_loss improved from 1.10435 to 1.08828, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8377 - accuracy: 0.6181 - val_loss: 1.0883 - val_accuracy: 0.4722 - 199ms/epoch - 22ms/step
# Epoch 69/300
#
# Epoch 69: val_loss improved from 1.08828 to 1.08747, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8523 - accuracy: 0.6597 - val_loss: 1.0875 - val_accuracy: 0.4861 - 201ms/epoch - 22ms/step
# Epoch 70/300
#
# Epoch 70: val_loss improved from 1.08747 to 1.08102, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8091 - accuracy: 0.7083 - val_loss: 1.0810 - val_accuracy: 0.5000 - 202ms/epoch - 22ms/step
# Epoch 71/300
#
# Epoch 71: val_loss improved from 1.08102 to 1.06077, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8285 - accuracy: 0.7153 - val_loss: 1.0608 - val_accuracy: 0.4722 - 200ms/epoch - 22ms/step
# Epoch 72/300
#
# Epoch 72: val_loss did not improve from 1.06077
# 9/9 - 0s - loss: 0.8332 - accuracy: 0.6597 - val_loss: 1.0722 - val_accuracy: 0.4722 - 189ms/epoch - 21ms/step
# Epoch 73/300
#
# Epoch 73: val_loss did not improve from 1.06077
# 9/9 - 0s - loss: 0.8187 - accuracy: 0.6458 - val_loss: 1.0628 - val_accuracy: 0.4861 - 185ms/epoch - 21ms/step
# Epoch 74/300
#
# Epoch 74: val_loss improved from 1.06077 to 1.05728, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8317 - accuracy: 0.6250 - val_loss: 1.0573 - val_accuracy: 0.5139 - 203ms/epoch - 23ms/step
# Epoch 75/300
#
# Epoch 75: val_loss improved from 1.05728 to 1.04970, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8509 - accuracy: 0.6667 - val_loss: 1.0497 - val_accuracy: 0.5278 - 202ms/epoch - 22ms/step
# Epoch 76/300
#
# Epoch 76: val_loss did not improve from 1.04970
# 9/9 - 0s - loss: 0.8302 - accuracy: 0.6250 - val_loss: 1.0497 - val_accuracy: 0.4861 - 193ms/epoch - 21ms/step
# Epoch 77/300
#
# Epoch 77: val_loss improved from 1.04970 to 1.02641, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.8059 - accuracy: 0.6736 - val_loss: 1.0264 - val_accuracy: 0.5417 - 202ms/epoch - 22ms/step
# Epoch 78/300
#
# Epoch 78: val_loss did not improve from 1.02641
# 9/9 - 0s - loss: 0.7950 - accuracy: 0.7500 - val_loss: 1.0341 - val_accuracy: 0.4722 - 189ms/epoch - 21ms/step
# Epoch 79/300
#
# Epoch 79: val_loss did not improve from 1.02641
# 9/9 - 0s - loss: 0.7678 - accuracy: 0.7708 - val_loss: 1.0283 - val_accuracy: 0.5000 - 189ms/epoch - 21ms/step
# Epoch 80/300
#
# Epoch 80: val_loss improved from 1.02641 to 1.02118, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7654 - accuracy: 0.7292 - val_loss: 1.0212 - val_accuracy: 0.5556 - 202ms/epoch - 22ms/step
# Epoch 81/300
#
# Epoch 81: val_loss improved from 1.02118 to 0.99505, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7948 - accuracy: 0.7153 - val_loss: 0.9951 - val_accuracy: 0.5972 - 203ms/epoch - 23ms/step
# Epoch 82/300
#
# Epoch 82: val_loss did not improve from 0.99505
# 9/9 - 0s - loss: 0.7606 - accuracy: 0.7222 - val_loss: 1.0145 - val_accuracy: 0.5278 - 187ms/epoch - 21ms/step
# Epoch 83/300
#
# Epoch 83: val_loss improved from 0.99505 to 0.97210, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7568 - accuracy: 0.7639 - val_loss: 0.9721 - val_accuracy: 0.6111 - 204ms/epoch - 23ms/step
# Epoch 84/300
#
# Epoch 84: val_loss did not improve from 0.97210
# 9/9 - 0s - loss: 0.7683 - accuracy: 0.7361 - val_loss: 0.9802 - val_accuracy: 0.5556 - 191ms/epoch - 21ms/step
# Epoch 85/300
#
# Epoch 85: val_loss improved from 0.97210 to 0.96580, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7863 - accuracy: 0.7292 - val_loss: 0.9658 - val_accuracy: 0.6111 - 207ms/epoch - 23ms/step
# Epoch 86/300
#
# Epoch 86: val_loss improved from 0.96580 to 0.96339, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7451 - accuracy: 0.7431 - val_loss: 0.9634 - val_accuracy: 0.6389 - 206ms/epoch - 23ms/step
# Epoch 87/300
#
# Epoch 87: val_loss did not improve from 0.96339
# 9/9 - 0s - loss: 0.7897 - accuracy: 0.7361 - val_loss: 0.9789 - val_accuracy: 0.5556 - 188ms/epoch - 21ms/step
# Epoch 88/300
#
# Epoch 88: val_loss improved from 0.96339 to 0.94162, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7511 - accuracy: 0.7778 - val_loss: 0.9416 - val_accuracy: 0.6250 - 202ms/epoch - 22ms/step
# Epoch 89/300
#
# Epoch 89: val_loss did not improve from 0.94162
# 9/9 - 0s - loss: 0.7674 - accuracy: 0.7569 - val_loss: 0.9521 - val_accuracy: 0.6111 - 188ms/epoch - 21ms/step
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 0.94162
# 9/9 - 0s - loss: 0.7582 - accuracy: 0.7222 - val_loss: 0.9491 - val_accuracy: 0.6250 - 190ms/epoch - 21ms/step
# Epoch 91/300
#
# Epoch 91: val_loss did not improve from 0.94162
# 9/9 - 0s - loss: 0.7452 - accuracy: 0.7222 - val_loss: 0.9428 - val_accuracy: 0.6250 - 190ms/epoch - 21ms/step
# Epoch 92/300
#
# Epoch 92: val_loss improved from 0.94162 to 0.94021, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7395 - accuracy: 0.7292 - val_loss: 0.9402 - val_accuracy: 0.5556 - 201ms/epoch - 22ms/step
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 0.94021
# 9/9 - 0s - loss: 0.7321 - accuracy: 0.7500 - val_loss: 0.9564 - val_accuracy: 0.5556 - 191ms/epoch - 21ms/step
# Epoch 94/300
#
# Epoch 94: val_loss improved from 0.94021 to 0.93600, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7451 - accuracy: 0.7222 - val_loss: 0.9360 - val_accuracy: 0.5694 - 223ms/epoch - 25ms/step
# Epoch 95/300
#
# Epoch 95: val_loss improved from 0.93600 to 0.91070, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7190 - accuracy: 0.7847 - val_loss: 0.9107 - val_accuracy: 0.5833 - 203ms/epoch - 23ms/step
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.91070
# 9/9 - 0s - loss: 0.7362 - accuracy: 0.7292 - val_loss: 0.9129 - val_accuracy: 0.5833 - 186ms/epoch - 21ms/step
# Epoch 97/300
#
# Epoch 97: val_loss improved from 0.91070 to 0.90798, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7068 - accuracy: 0.7639 - val_loss: 0.9080 - val_accuracy: 0.5833 - 204ms/epoch - 23ms/step
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.90798
# 9/9 - 0s - loss: 0.7604 - accuracy: 0.7361 - val_loss: 0.9231 - val_accuracy: 0.6528 - 192ms/epoch - 21ms/step
# Epoch 99/300
#
# Epoch 99: val_loss did not improve from 0.90798
# 9/9 - 0s - loss: 0.7502 - accuracy: 0.7569 - val_loss: 0.9884 - val_accuracy: 0.5694 - 187ms/epoch - 21ms/step
# Epoch 100/300
#
# Epoch 100: val_loss improved from 0.90798 to 0.90187, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7316 - accuracy: 0.7569 - val_loss: 0.9019 - val_accuracy: 0.6250 - 206ms/epoch - 23ms/step
# Epoch 101/300
#
# Epoch 101: val_loss did not improve from 0.90187
# 9/9 - 0s - loss: 0.7202 - accuracy: 0.7778 - val_loss: 0.9235 - val_accuracy: 0.6111 - 195ms/epoch - 22ms/step
# Epoch 102/300
#
# Epoch 102: val_loss improved from 0.90187 to 0.89530, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7442 - accuracy: 0.7708 - val_loss: 0.8953 - val_accuracy: 0.6528 - 202ms/epoch - 22ms/step
# Epoch 103/300
#
# Epoch 103: val_loss did not improve from 0.89530
# 9/9 - 0s - loss: 0.6908 - accuracy: 0.8194 - val_loss: 0.9025 - val_accuracy: 0.6111 - 192ms/epoch - 21ms/step
# Epoch 104/300
#
# Epoch 104: val_loss did not improve from 0.89530
# 9/9 - 0s - loss: 0.7350 - accuracy: 0.7639 - val_loss: 0.8994 - val_accuracy: 0.6250 - 191ms/epoch - 21ms/step
# Epoch 105/300
#
# Epoch 105: val_loss did not improve from 0.89530
# 9/9 - 0s - loss: 0.7125 - accuracy: 0.7500 - val_loss: 0.9212 - val_accuracy: 0.5972 - 186ms/epoch - 21ms/step
# Epoch 106/300
#
# Epoch 106: val_loss improved from 0.89530 to 0.88252, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.7225 - accuracy: 0.7639 - val_loss: 0.8825 - val_accuracy: 0.6944 - 207ms/epoch - 23ms/step
# Epoch 107/300
#
# Epoch 107: val_loss did not improve from 0.88252
# 9/9 - 0s - loss: 0.7160 - accuracy: 0.7847 - val_loss: 0.9056 - val_accuracy: 0.6250 - 190ms/epoch - 21ms/step
# Epoch 108/300
#
# Epoch 108: val_loss did not improve from 0.88252
# 9/9 - 0s - loss: 0.7033 - accuracy: 0.7778 - val_loss: 0.9026 - val_accuracy: 0.6528 - 193ms/epoch - 21ms/step
# Epoch 109/300
#
# Epoch 109: val_loss did not improve from 0.88252
# 9/9 - 0s - loss: 0.7080 - accuracy: 0.7847 - val_loss: 0.8944 - val_accuracy: 0.6667 - 188ms/epoch - 21ms/step
# Epoch 110/300
#
# Epoch 110: val_loss did not improve from 0.88252
# 9/9 - 0s - loss: 0.7096 - accuracy: 0.7361 - val_loss: 0.8948 - val_accuracy: 0.6389 - 185ms/epoch - 21ms/step
# Epoch 111/300
#
# Epoch 111: val_loss improved from 0.88252 to 0.87762, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6883 - accuracy: 0.8194 - val_loss: 0.8776 - val_accuracy: 0.6389 - 204ms/epoch - 23ms/step
# Epoch 112/300
#
# Epoch 112: val_loss improved from 0.87762 to 0.86489, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6866 - accuracy: 0.7917 - val_loss: 0.8649 - val_accuracy: 0.6667 - 203ms/epoch - 23ms/step
# Epoch 113/300
#
# Epoch 113: val_loss did not improve from 0.86489
# 9/9 - 0s - loss: 0.6825 - accuracy: 0.8194 - val_loss: 0.8723 - val_accuracy: 0.6389 - 193ms/epoch - 21ms/step
# Epoch 114/300
#
# Epoch 114: val_loss improved from 0.86489 to 0.85019, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6818 - accuracy: 0.7917 - val_loss: 0.8502 - val_accuracy: 0.6250 - 207ms/epoch - 23ms/step
# Epoch 115/300
#
# Epoch 115: val_loss did not improve from 0.85019
# 9/9 - 0s - loss: 0.6674 - accuracy: 0.7917 - val_loss: 0.8786 - val_accuracy: 0.6250 - 192ms/epoch - 21ms/step
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.85019
# 9/9 - 0s - loss: 0.6769 - accuracy: 0.7639 - val_loss: 0.8777 - val_accuracy: 0.5972 - 189ms/epoch - 21ms/step
# Epoch 117/300
#
# Epoch 117: val_loss did not improve from 0.85019
# 9/9 - 0s - loss: 0.6341 - accuracy: 0.8264 - val_loss: 0.8602 - val_accuracy: 0.7222 - 190ms/epoch - 21ms/step
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.85019
# 9/9 - 0s - loss: 0.6401 - accuracy: 0.8681 - val_loss: 0.8644 - val_accuracy: 0.6528 - 188ms/epoch - 21ms/step
# Epoch 119/300
#
# Epoch 119: val_loss improved from 0.85019 to 0.83071, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6980 - accuracy: 0.7847 - val_loss: 0.8307 - val_accuracy: 0.6806 - 200ms/epoch - 22ms/step
# Epoch 120/300
#
# Epoch 120: val_loss did not improve from 0.83071
# 9/9 - 0s - loss: 0.6859 - accuracy: 0.7569 - val_loss: 0.8647 - val_accuracy: 0.6389 - 189ms/epoch - 21ms/step
# Epoch 121/300
#
# Epoch 121: val_loss did not improve from 0.83071
# 9/9 - 0s - loss: 0.6496 - accuracy: 0.8333 - val_loss: 0.8327 - val_accuracy: 0.6528 - 192ms/epoch - 21ms/step
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.83071
# 9/9 - 0s - loss: 0.6520 - accuracy: 0.8194 - val_loss: 0.8563 - val_accuracy: 0.6528 - 214ms/epoch - 24ms/step
# Epoch 123/300
#
# Epoch 123: val_loss improved from 0.83071 to 0.82452, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6342 - accuracy: 0.8403 - val_loss: 0.8245 - val_accuracy: 0.6389 - 201ms/epoch - 22ms/step
# Epoch 124/300
#
# Epoch 124: val_loss did not improve from 0.82452
# 9/9 - 0s - loss: 0.6314 - accuracy: 0.8333 - val_loss: 0.8414 - val_accuracy: 0.6806 - 201ms/epoch - 22ms/step
# Epoch 125/300
#
# Epoch 125: val_loss did not improve from 0.82452
# 9/9 - 0s - loss: 0.6496 - accuracy: 0.7708 - val_loss: 0.8339 - val_accuracy: 0.6667 - 187ms/epoch - 21ms/step
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.82452
# 9/9 - 0s - loss: 0.6123 - accuracy: 0.8264 - val_loss: 0.8491 - val_accuracy: 0.6667 - 193ms/epoch - 21ms/step
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.82452
# 9/9 - 0s - loss: 0.6234 - accuracy: 0.7986 - val_loss: 0.8330 - val_accuracy: 0.6806 - 190ms/epoch - 21ms/step
# Epoch 128/300
#
# Epoch 128: val_loss improved from 0.82452 to 0.79935, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.6233 - accuracy: 0.8125 - val_loss: 0.7994 - val_accuracy: 0.6806 - 211ms/epoch - 23ms/step
# Epoch 129/300
#
# Epoch 129: val_loss did not improve from 0.79935
# 9/9 - 0s - loss: 0.6404 - accuracy: 0.8264 - val_loss: 0.8552 - val_accuracy: 0.6250 - 189ms/epoch - 21ms/step
# Epoch 130/300
#
# Epoch 130: val_loss did not improve from 0.79935
# 9/9 - 0s - loss: 0.6199 - accuracy: 0.8403 - val_loss: 0.8161 - val_accuracy: 0.6806 - 189ms/epoch - 21ms/step
# Epoch 131/300
#
# Epoch 131: val_loss did not improve from 0.79935
# 9/9 - 0s - loss: 0.5989 - accuracy: 0.8125 - val_loss: 0.8002 - val_accuracy: 0.6667 - 193ms/epoch - 21ms/step
# Epoch 132/300
#
# Epoch 132: val_loss did not improve from 0.79935
# 9/9 - 0s - loss: 0.6246 - accuracy: 0.8194 - val_loss: 0.8309 - val_accuracy: 0.6528 - 192ms/epoch - 21ms/step
# Epoch 133/300
#
# Epoch 133: val_loss did not improve from 0.79935
# 9/9 - 0s - loss: 0.5832 - accuracy: 0.8472 - val_loss: 0.8141 - val_accuracy: 0.6528 - 192ms/epoch - 21ms/step
# Epoch 134/300
#
# Epoch 134: val_loss did not improve from 0.79935
# 9/9 - 0s - loss: 0.5945 - accuracy: 0.8611 - val_loss: 0.8312 - val_accuracy: 0.7222 - 195ms/epoch - 22ms/step
# Epoch 135/300
#
# Epoch 135: val_loss did not improve from 0.79935
# 9/9 - 0s - loss: 0.5610 - accuracy: 0.8889 - val_loss: 0.8020 - val_accuracy: 0.7083 - 193ms/epoch - 21ms/step
# Epoch 136/300
#
# Epoch 136: val_loss did not improve from 0.79935
# 9/9 - 0s - loss: 0.6394 - accuracy: 0.7986 - val_loss: 0.8169 - val_accuracy: 0.7083 - 191ms/epoch - 21ms/step
# Epoch 137/300
#
# Epoch 137: val_loss did not improve from 0.79935
# 9/9 - 0s - loss: 0.6181 - accuracy: 0.8333 - val_loss: 0.8297 - val_accuracy: 0.6944 - 190ms/epoch - 21ms/step
# Epoch 138/300
#
# Epoch 138: val_loss did not improve from 0.79935
# 9/9 - 0s - loss: 0.5965 - accuracy: 0.8542 - val_loss: 0.7999 - val_accuracy: 0.6944 - 187ms/epoch - 21ms/step
# Epoch 139/300
#
# Epoch 139: val_loss improved from 0.79935 to 0.78973, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5859 - accuracy: 0.8472 - val_loss: 0.7897 - val_accuracy: 0.6806 - 207ms/epoch - 23ms/step
# Epoch 140/300
#
# Epoch 140: val_loss improved from 0.78973 to 0.78221, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5559 - accuracy: 0.8958 - val_loss: 0.7822 - val_accuracy: 0.6389 - 201ms/epoch - 22ms/step
# Epoch 141/300
#
# Epoch 141: val_loss did not improve from 0.78221
# 9/9 - 0s - loss: 0.5809 - accuracy: 0.8542 - val_loss: 0.8152 - val_accuracy: 0.6528 - 197ms/epoch - 22ms/step
# Epoch 142/300
#
# Epoch 142: val_loss improved from 0.78221 to 0.75918, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5576 - accuracy: 0.8819 - val_loss: 0.7592 - val_accuracy: 0.6806 - 205ms/epoch - 23ms/step
# Epoch 143/300
#
# Epoch 143: val_loss did not improve from 0.75918
# 9/9 - 0s - loss: 0.6270 - accuracy: 0.8681 - val_loss: 0.7701 - val_accuracy: 0.6389 - 190ms/epoch - 21ms/step
# Epoch 144/300
#
# Epoch 144: val_loss did not improve from 0.75918
# 9/9 - 0s - loss: 0.5701 - accuracy: 0.8819 - val_loss: 0.7736 - val_accuracy: 0.7083 - 189ms/epoch - 21ms/step
# Epoch 145/300
#
# Epoch 145: val_loss did not improve from 0.75918
# 9/9 - 0s - loss: 0.5175 - accuracy: 0.9167 - val_loss: 0.7670 - val_accuracy: 0.6944 - 187ms/epoch - 21ms/step
# Epoch 146/300
#
# Epoch 146: val_loss did not improve from 0.75918
# 9/9 - 0s - loss: 0.5389 - accuracy: 0.8889 - val_loss: 0.7842 - val_accuracy: 0.6806 - 196ms/epoch - 22ms/step
# Epoch 147/300
#
# Epoch 147: val_loss did not improve from 0.75918
# 9/9 - 0s - loss: 0.5985 - accuracy: 0.8472 - val_loss: 0.7728 - val_accuracy: 0.6667 - 192ms/epoch - 21ms/step
# Epoch 148/300
#
# Epoch 148: val_loss did not improve from 0.75918
# 9/9 - 0s - loss: 0.5772 - accuracy: 0.8611 - val_loss: 0.7599 - val_accuracy: 0.6944 - 191ms/epoch - 21ms/step
# Epoch 149/300
#
# Epoch 149: val_loss did not improve from 0.75918
# 9/9 - 0s - loss: 0.5451 - accuracy: 0.8542 - val_loss: 0.7709 - val_accuracy: 0.6944 - 193ms/epoch - 21ms/step
# Epoch 150/300
#
# Epoch 150: val_loss improved from 0.75918 to 0.75476, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5830 - accuracy: 0.8681 - val_loss: 0.7548 - val_accuracy: 0.7083 - 205ms/epoch - 23ms/step
# Epoch 151/300
#
# Epoch 151: val_loss did not improve from 0.75476
# 9/9 - 0s - loss: 0.5363 - accuracy: 0.8125 - val_loss: 0.7554 - val_accuracy: 0.6806 - 192ms/epoch - 21ms/step
# Epoch 152/300
#
# Epoch 152: val_loss improved from 0.75476 to 0.72932, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5274 - accuracy: 0.8889 - val_loss: 0.7293 - val_accuracy: 0.6944 - 222ms/epoch - 25ms/step
# Epoch 153/300
#
# Epoch 153: val_loss did not improve from 0.72932
# 9/9 - 0s - loss: 0.5359 - accuracy: 0.8750 - val_loss: 0.7638 - val_accuracy: 0.7083 - 186ms/epoch - 21ms/step
# Epoch 154/300
#
# Epoch 154: val_loss did not improve from 0.72932
# 9/9 - 0s - loss: 0.5642 - accuracy: 0.8403 - val_loss: 0.7396 - val_accuracy: 0.7083 - 191ms/epoch - 21ms/step
# Epoch 155/300
#
# Epoch 155: val_loss improved from 0.72932 to 0.72912, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5006 - accuracy: 0.8819 - val_loss: 0.7291 - val_accuracy: 0.7500 - 202ms/epoch - 22ms/step
# Epoch 156/300
#
# Epoch 156: val_loss improved from 0.72912 to 0.72367, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.4990 - accuracy: 0.9306 - val_loss: 0.7237 - val_accuracy: 0.6944 - 205ms/epoch - 23ms/step
# Epoch 157/300
#
# Epoch 157: val_loss did not improve from 0.72367
# 9/9 - 0s - loss: 0.4785 - accuracy: 0.9583 - val_loss: 0.7255 - val_accuracy: 0.6944 - 187ms/epoch - 21ms/step
# Epoch 158/300
#
# Epoch 158: val_loss did not improve from 0.72367
# 9/9 - 0s - loss: 0.5172 - accuracy: 0.8681 - val_loss: 0.7510 - val_accuracy: 0.7222 - 197ms/epoch - 22ms/step
# Epoch 159/300
#
# Epoch 159: val_loss did not improve from 0.72367
# 9/9 - 0s - loss: 0.5202 - accuracy: 0.8819 - val_loss: 0.7417 - val_accuracy: 0.7778 - 197ms/epoch - 22ms/step
# Epoch 160/300
#
# Epoch 160: val_loss did not improve from 0.72367
# 9/9 - 0s - loss: 0.4831 - accuracy: 0.9167 - val_loss: 0.7388 - val_accuracy: 0.7222 - 200ms/epoch - 22ms/step
# Epoch 161/300
#
# Epoch 161: val_loss improved from 0.72367 to 0.70061, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5502 - accuracy: 0.7986 - val_loss: 0.7006 - val_accuracy: 0.7917 - 204ms/epoch - 23ms/step
# Epoch 162/300
#
# Epoch 162: val_loss did not improve from 0.70061
# 9/9 - 0s - loss: 0.4940 - accuracy: 0.9236 - val_loss: 0.7321 - val_accuracy: 0.7500 - 196ms/epoch - 22ms/step
# Epoch 163/300
#
# Epoch 163: val_loss did not improve from 0.70061
# 9/9 - 0s - loss: 0.4938 - accuracy: 0.8958 - val_loss: 0.7390 - val_accuracy: 0.7083 - 205ms/epoch - 23ms/step
# Epoch 164/300
#
# Epoch 164: val_loss did not improve from 0.70061
# 9/9 - 0s - loss: 0.5128 - accuracy: 0.8819 - val_loss: 0.7301 - val_accuracy: 0.7778 - 195ms/epoch - 22ms/step
# Epoch 165/300
#
# Epoch 165: val_loss improved from 0.70061 to 0.69077, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.5112 - accuracy: 0.9097 - val_loss: 0.6908 - val_accuracy: 0.7778 - 213ms/epoch - 24ms/step
# Epoch 166/300
#
# Epoch 166: val_loss did not improve from 0.69077
# 9/9 - 0s - loss: 0.4909 - accuracy: 0.8819 - val_loss: 0.7027 - val_accuracy: 0.7778 - 190ms/epoch - 21ms/step
# Epoch 167/300
#
# Epoch 167: val_loss did not improve from 0.69077
# 9/9 - 0s - loss: 0.4993 - accuracy: 0.8750 - val_loss: 0.7467 - val_accuracy: 0.7778 - 193ms/epoch - 21ms/step
# Epoch 168/300
#
# Epoch 168: val_loss did not improve from 0.69077
# 9/9 - 0s - loss: 0.4821 - accuracy: 0.9028 - val_loss: 0.7356 - val_accuracy: 0.7500 - 193ms/epoch - 21ms/step
# Epoch 169/300
#
# Epoch 169: val_loss did not improve from 0.69077
# 9/9 - 0s - loss: 0.4593 - accuracy: 0.9028 - val_loss: 0.7555 - val_accuracy: 0.6667 - 194ms/epoch - 22ms/step
# Epoch 170/300
#
# Epoch 170: val_loss did not improve from 0.69077
# 9/9 - 0s - loss: 0.4630 - accuracy: 0.9167 - val_loss: 0.6989 - val_accuracy: 0.8056 - 193ms/epoch - 21ms/step
# Epoch 171/300
#
# Epoch 171: val_loss did not improve from 0.69077
# 9/9 - 0s - loss: 0.3880 - accuracy: 0.9722 - val_loss: 0.7196 - val_accuracy: 0.6667 - 196ms/epoch - 22ms/step
# Epoch 172/300
#
# Epoch 172: val_loss did not improve from 0.69077
# 9/9 - 0s - loss: 0.4197 - accuracy: 0.9375 - val_loss: 0.6984 - val_accuracy: 0.7500 - 197ms/epoch - 22ms/step
# Epoch 173/300
#
# Epoch 173: val_loss improved from 0.69077 to 0.68613, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.4445 - accuracy: 0.8750 - val_loss: 0.6861 - val_accuracy: 0.7639 - 212ms/epoch - 24ms/step
# Epoch 174/300
#
# Epoch 174: val_loss did not improve from 0.68613
# 9/9 - 0s - loss: 0.4801 - accuracy: 0.8889 - val_loss: 0.6982 - val_accuracy: 0.7639 - 191ms/epoch - 21ms/step
# Epoch 175/300
#
# Epoch 175: val_loss improved from 0.68613 to 0.67322, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.4672 - accuracy: 0.8819 - val_loss: 0.6732 - val_accuracy: 0.7361 - 208ms/epoch - 23ms/step
# Epoch 176/300
#
# Epoch 176: val_loss did not improve from 0.67322
# 9/9 - 0s - loss: 0.4202 - accuracy: 0.9167 - val_loss: 0.6978 - val_accuracy: 0.7917 - 197ms/epoch - 22ms/step
# Epoch 177/300
#
# Epoch 177: val_loss did not improve from 0.67322
# 9/9 - 0s - loss: 0.4439 - accuracy: 0.9028 - val_loss: 0.6837 - val_accuracy: 0.7917 - 193ms/epoch - 21ms/step
# Epoch 178/300
#
# Epoch 178: val_loss did not improve from 0.67322
# 9/9 - 0s - loss: 0.5002 - accuracy: 0.8681 - val_loss: 0.6943 - val_accuracy: 0.7500 - 192ms/epoch - 21ms/step
# Epoch 179/300
#
# Epoch 179: val_loss did not improve from 0.67322
# 9/9 - 0s - loss: 0.5171 - accuracy: 0.8542 - val_loss: 0.7010 - val_accuracy: 0.7917 - 210ms/epoch - 23ms/step
# Epoch 180/300
#
# Epoch 180: val_loss did not improve from 0.67322
# 9/9 - 0s - loss: 0.4222 - accuracy: 0.9306 - val_loss: 0.6837 - val_accuracy: 0.7778 - 207ms/epoch - 23ms/step
# Epoch 181/300
#
# Epoch 181: val_loss improved from 0.67322 to 0.63990, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.4203 - accuracy: 0.9167 - val_loss: 0.6399 - val_accuracy: 0.8194 - 210ms/epoch - 23ms/step
# Epoch 182/300
#
# Epoch 182: val_loss did not improve from 0.63990
# 9/9 - 0s - loss: 0.4134 - accuracy: 0.9167 - val_loss: 0.6837 - val_accuracy: 0.7639 - 213ms/epoch - 24ms/step
# Epoch 183/300
#
# Epoch 183: val_loss improved from 0.63990 to 0.63823, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3936 - accuracy: 0.9028 - val_loss: 0.6382 - val_accuracy: 0.7917 - 216ms/epoch - 24ms/step
# Epoch 184/300
#
# Epoch 184: val_loss did not improve from 0.63823
# 9/9 - 0s - loss: 0.4718 - accuracy: 0.8819 - val_loss: 0.6771 - val_accuracy: 0.7778 - 231ms/epoch - 26ms/step
# Epoch 185/300
#
# Epoch 185: val_loss did not improve from 0.63823
# 9/9 - 0s - loss: 0.5153 - accuracy: 0.8889 - val_loss: 0.6590 - val_accuracy: 0.7500 - 225ms/epoch - 25ms/step
# Epoch 186/300
#
# Epoch 186: val_loss did not improve from 0.63823
# 9/9 - 0s - loss: 0.4332 - accuracy: 0.8889 - val_loss: 0.6435 - val_accuracy: 0.7778 - 203ms/epoch - 23ms/step
# Epoch 187/300
#
# Epoch 187: val_loss did not improve from 0.63823
# 9/9 - 0s - loss: 0.4202 - accuracy: 0.9028 - val_loss: 0.6409 - val_accuracy: 0.7361 - 209ms/epoch - 23ms/step
# Epoch 188/300
#
# Epoch 188: val_loss improved from 0.63823 to 0.62749, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.4517 - accuracy: 0.9028 - val_loss: 0.6275 - val_accuracy: 0.8194 - 218ms/epoch - 24ms/step
# Epoch 189/300
#
# Epoch 189: val_loss did not improve from 0.62749
# 9/9 - 0s - loss: 0.4685 - accuracy: 0.9028 - val_loss: 0.6592 - val_accuracy: 0.7778 - 198ms/epoch - 22ms/step
# Epoch 190/300
#
# Epoch 190: val_loss did not improve from 0.62749
# 9/9 - 0s - loss: 0.4739 - accuracy: 0.8681 - val_loss: 0.6516 - val_accuracy: 0.7778 - 203ms/epoch - 23ms/step
# Epoch 191/300
#
# Epoch 191: val_loss did not improve from 0.62749
# 9/9 - 0s - loss: 0.4578 - accuracy: 0.8542 - val_loss: 0.6843 - val_accuracy: 0.6944 - 200ms/epoch - 22ms/step
# Epoch 192/300
#
# Epoch 192: val_loss did not improve from 0.62749
# 9/9 - 0s - loss: 0.4413 - accuracy: 0.9028 - val_loss: 0.6442 - val_accuracy: 0.7917 - 208ms/epoch - 23ms/step
# Epoch 193/300
#
# Epoch 193: val_loss did not improve from 0.62749
# 9/9 - 0s - loss: 0.4020 - accuracy: 0.8889 - val_loss: 0.6462 - val_accuracy: 0.8056 - 201ms/epoch - 22ms/step
# Epoch 194/300
#
# Epoch 194: val_loss did not improve from 0.62749
# 9/9 - 0s - loss: 0.4297 - accuracy: 0.9306 - val_loss: 0.6517 - val_accuracy: 0.7639 - 199ms/epoch - 22ms/step
# Epoch 195/300
#
# Epoch 195: val_loss did not improve from 0.62749
# 9/9 - 0s - loss: 0.4165 - accuracy: 0.9236 - val_loss: 0.6333 - val_accuracy: 0.8194 - 207ms/epoch - 23ms/step
# Epoch 196/300
#
# Epoch 196: val_loss did not improve from 0.62749
# 9/9 - 0s - loss: 0.4058 - accuracy: 0.8958 - val_loss: 0.6276 - val_accuracy: 0.8333 - 195ms/epoch - 22ms/step
# Epoch 197/300
#
# Epoch 197: val_loss did not improve from 0.62749
# 9/9 - 0s - loss: 0.4161 - accuracy: 0.9236 - val_loss: 0.6717 - val_accuracy: 0.8194 - 206ms/epoch - 23ms/step
# Epoch 198/300
#
# Epoch 198: val_loss did not improve from 0.62749
# 9/9 - 0s - loss: 0.3949 - accuracy: 0.9028 - val_loss: 0.6392 - val_accuracy: 0.7917 - 202ms/epoch - 22ms/step
# Epoch 199/300
#
# Epoch 199: val_loss did not improve from 0.62749
# 9/9 - 0s - loss: 0.4130 - accuracy: 0.9167 - val_loss: 0.6919 - val_accuracy: 0.7917 - 198ms/epoch - 22ms/step
# Epoch 200/300
#
# Epoch 200: val_loss did not improve from 0.62749
# 9/9 - 0s - loss: 0.4019 - accuracy: 0.8889 - val_loss: 0.6534 - val_accuracy: 0.7778 - 208ms/epoch - 23ms/step
# Epoch 201/300
#
# Epoch 201: val_loss improved from 0.62749 to 0.60818, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3867 - accuracy: 0.9514 - val_loss: 0.6082 - val_accuracy: 0.8194 - 220ms/epoch - 24ms/step
# Epoch 202/300
#
# Epoch 202: val_loss did not improve from 0.60818
# 9/9 - 0s - loss: 0.4300 - accuracy: 0.9097 - val_loss: 0.6624 - val_accuracy: 0.7639 - 194ms/epoch - 22ms/step
# Epoch 203/300
#
# Epoch 203: val_loss did not improve from 0.60818
# 9/9 - 0s - loss: 0.4177 - accuracy: 0.9236 - val_loss: 0.6470 - val_accuracy: 0.7917 - 198ms/epoch - 22ms/step
# Epoch 204/300
#
# Epoch 204: val_loss did not improve from 0.60818
# 9/9 - 0s - loss: 0.4364 - accuracy: 0.9167 - val_loss: 0.6291 - val_accuracy: 0.7778 - 197ms/epoch - 22ms/step
# Epoch 205/300
#
# Epoch 205: val_loss did not improve from 0.60818
# 9/9 - 0s - loss: 0.3751 - accuracy: 0.9514 - val_loss: 0.6437 - val_accuracy: 0.7361 - 197ms/epoch - 22ms/step
# Epoch 206/300
#
# Epoch 206: val_loss did not improve from 0.60818
# 9/9 - 0s - loss: 0.4061 - accuracy: 0.9097 - val_loss: 0.6465 - val_accuracy: 0.7778 - 197ms/epoch - 22ms/step
# Epoch 207/300
#
# Epoch 207: val_loss did not improve from 0.60818
# 9/9 - 0s - loss: 0.3772 - accuracy: 0.9306 - val_loss: 0.6422 - val_accuracy: 0.7917 - 194ms/epoch - 22ms/step
# Epoch 208/300
#
# Epoch 208: val_loss did not improve from 0.60818
# 9/9 - 0s - loss: 0.3867 - accuracy: 0.8889 - val_loss: 0.6270 - val_accuracy: 0.8056 - 207ms/epoch - 23ms/step
# Epoch 209/300
#
# Epoch 209: val_loss did not improve from 0.60818
# 9/9 - 0s - loss: 0.3621 - accuracy: 0.9444 - val_loss: 0.6365 - val_accuracy: 0.7778 - 198ms/epoch - 22ms/step
# Epoch 210/300
#
# Epoch 210: val_loss did not improve from 0.60818
# 9/9 - 0s - loss: 0.4292 - accuracy: 0.9028 - val_loss: 0.6201 - val_accuracy: 0.7917 - 208ms/epoch - 23ms/step
# Epoch 211/300
#
# Epoch 211: val_loss did not improve from 0.60818
# 9/9 - 0s - loss: 0.3889 - accuracy: 0.9097 - val_loss: 0.6162 - val_accuracy: 0.8056 - 195ms/epoch - 22ms/step
# Epoch 212/300
#
# Epoch 212: val_loss did not improve from 0.60818
# 9/9 - 0s - loss: 0.3530 - accuracy: 0.9236 - val_loss: 0.6285 - val_accuracy: 0.7639 - 199ms/epoch - 22ms/step
# Epoch 213/300
#
# Epoch 213: val_loss improved from 0.60818 to 0.58666, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3530 - accuracy: 0.9583 - val_loss: 0.5867 - val_accuracy: 0.8333 - 217ms/epoch - 24ms/step
# Epoch 214/300
#
# Epoch 214: val_loss improved from 0.58666 to 0.58661, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3765 - accuracy: 0.9167 - val_loss: 0.5866 - val_accuracy: 0.7917 - 213ms/epoch - 24ms/step
# Epoch 215/300
#
# Epoch 215: val_loss did not improve from 0.58661
# 9/9 - 0s - loss: 0.3535 - accuracy: 0.9375 - val_loss: 0.6013 - val_accuracy: 0.8194 - 209ms/epoch - 23ms/step
# Epoch 216/300
#
# Epoch 216: val_loss did not improve from 0.58661
# 9/9 - 0s - loss: 0.3438 - accuracy: 0.9444 - val_loss: 0.6053 - val_accuracy: 0.8194 - 205ms/epoch - 23ms/step
# Epoch 217/300
#
# Epoch 217: val_loss did not improve from 0.58661
# 9/9 - 0s - loss: 0.3715 - accuracy: 0.9444 - val_loss: 0.6445 - val_accuracy: 0.7361 - 195ms/epoch - 22ms/step
# Epoch 218/300
#
# Epoch 218: val_loss did not improve from 0.58661
# 9/9 - 0s - loss: 0.3955 - accuracy: 0.9028 - val_loss: 0.6432 - val_accuracy: 0.7639 - 197ms/epoch - 22ms/step
# Epoch 219/300
#
# Epoch 219: val_loss did not improve from 0.58661
# 9/9 - 0s - loss: 0.4086 - accuracy: 0.8889 - val_loss: 0.6595 - val_accuracy: 0.7361 - 198ms/epoch - 22ms/step
# Epoch 220/300
#
# Epoch 220: val_loss did not improve from 0.58661
# 9/9 - 0s - loss: 0.3637 - accuracy: 0.9444 - val_loss: 0.6491 - val_accuracy: 0.7500 - 197ms/epoch - 22ms/step
# Epoch 221/300
#
# Epoch 221: val_loss did not improve from 0.58661
# 9/9 - 0s - loss: 0.3766 - accuracy: 0.9236 - val_loss: 0.6150 - val_accuracy: 0.8333 - 196ms/epoch - 22ms/step
# Epoch 222/300
#
# Epoch 222: val_loss did not improve from 0.58661
# 9/9 - 0s - loss: 0.3682 - accuracy: 0.9028 - val_loss: 0.6263 - val_accuracy: 0.7500 - 198ms/epoch - 22ms/step
# Epoch 223/300
#
# Epoch 223: val_loss improved from 0.58661 to 0.58412, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3756 - accuracy: 0.9375 - val_loss: 0.5841 - val_accuracy: 0.8333 - 208ms/epoch - 23ms/step
# Epoch 224/300
#
# Epoch 224: val_loss did not improve from 0.58412
# 9/9 - 0s - loss: 0.3632 - accuracy: 0.9167 - val_loss: 0.6431 - val_accuracy: 0.7639 - 203ms/epoch - 23ms/step
# Epoch 225/300
#
# Epoch 225: val_loss did not improve from 0.58412
# 9/9 - 0s - loss: 0.3499 - accuracy: 0.9236 - val_loss: 0.6361 - val_accuracy: 0.7917 - 213ms/epoch - 24ms/step
# Epoch 226/300
#
# Epoch 226: val_loss did not improve from 0.58412
# 9/9 - 0s - loss: 0.3330 - accuracy: 0.9583 - val_loss: 0.6145 - val_accuracy: 0.7778 - 198ms/epoch - 22ms/step
# Epoch 227/300
#
# Epoch 227: val_loss improved from 0.58412 to 0.57646, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3462 - accuracy: 0.9306 - val_loss: 0.5765 - val_accuracy: 0.8750 - 212ms/epoch - 24ms/step
# Epoch 228/300
#
# Epoch 228: val_loss did not improve from 0.57646
# 9/9 - 0s - loss: 0.3707 - accuracy: 0.9236 - val_loss: 0.5937 - val_accuracy: 0.8194 - 214ms/epoch - 24ms/step
# Epoch 229/300
#
# Epoch 229: val_loss did not improve from 0.57646
# 9/9 - 0s - loss: 0.3775 - accuracy: 0.9028 - val_loss: 0.6484 - val_accuracy: 0.7917 - 202ms/epoch - 22ms/step
# Epoch 230/300
#
# Epoch 230: val_loss did not improve from 0.57646
# 9/9 - 0s - loss: 0.3903 - accuracy: 0.9097 - val_loss: 0.6588 - val_accuracy: 0.7639 - 194ms/epoch - 22ms/step
# Epoch 231/300
#
# Epoch 231: val_loss did not improve from 0.57646
# 9/9 - 0s - loss: 0.3489 - accuracy: 0.9306 - val_loss: 0.5814 - val_accuracy: 0.8056 - 193ms/epoch - 21ms/step
# Epoch 232/300
#
# Epoch 232: val_loss improved from 0.57646 to 0.57519, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3357 - accuracy: 0.9375 - val_loss: 0.5752 - val_accuracy: 0.8472 - 210ms/epoch - 23ms/step
# Epoch 233/300
#
# Epoch 233: val_loss did not improve from 0.57519
# 9/9 - 0s - loss: 0.3687 - accuracy: 0.8958 - val_loss: 0.6115 - val_accuracy: 0.7500 - 197ms/epoch - 22ms/step
# Epoch 234/300
#
# Epoch 234: val_loss improved from 0.57519 to 0.56246, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3693 - accuracy: 0.9097 - val_loss: 0.5625 - val_accuracy: 0.7778 - 214ms/epoch - 24ms/step
# Epoch 235/300
#
# Epoch 235: val_loss did not improve from 0.56246
# 9/9 - 0s - loss: 0.3200 - accuracy: 0.9306 - val_loss: 0.5760 - val_accuracy: 0.7917 - 195ms/epoch - 22ms/step
# Epoch 236/300
#
# Epoch 236: val_loss did not improve from 0.56246
# 9/9 - 0s - loss: 0.3748 - accuracy: 0.8889 - val_loss: 0.5998 - val_accuracy: 0.7778 - 198ms/epoch - 22ms/step
# Epoch 237/300
#
# Epoch 237: val_loss did not improve from 0.56246
# 9/9 - 0s - loss: 0.3210 - accuracy: 0.9236 - val_loss: 0.6030 - val_accuracy: 0.8333 - 214ms/epoch - 24ms/step
# Epoch 238/300
#
# Epoch 238: val_loss did not improve from 0.56246
# 9/9 - 0s - loss: 0.3588 - accuracy: 0.9236 - val_loss: 0.5933 - val_accuracy: 0.8056 - 196ms/epoch - 22ms/step
# Epoch 239/300
#
# Epoch 239: val_loss did not improve from 0.56246
# 9/9 - 0s - loss: 0.3597 - accuracy: 0.9236 - val_loss: 0.6074 - val_accuracy: 0.7917 - 193ms/epoch - 21ms/step
# Epoch 240/300
#
# Epoch 240: val_loss did not improve from 0.56246
# 9/9 - 0s - loss: 0.3497 - accuracy: 0.9097 - val_loss: 0.6236 - val_accuracy: 0.7500 - 195ms/epoch - 22ms/step
# Epoch 241/300
#
# Epoch 241: val_loss did not improve from 0.56246
# 9/9 - 0s - loss: 0.3637 - accuracy: 0.8889 - val_loss: 0.5932 - val_accuracy: 0.7500 - 196ms/epoch - 22ms/step
# Epoch 242/300
#
# Epoch 242: val_loss did not improve from 0.56246
# 9/9 - 0s - loss: 0.3082 - accuracy: 0.9583 - val_loss: 0.6025 - val_accuracy: 0.8056 - 193ms/epoch - 21ms/step
# Epoch 243/300
#
# Epoch 243: val_loss did not improve from 0.56246
# 9/9 - 0s - loss: 0.3285 - accuracy: 0.9444 - val_loss: 0.5659 - val_accuracy: 0.8611 - 207ms/epoch - 23ms/step
# Epoch 244/300
#
# Epoch 244: val_loss improved from 0.56246 to 0.54993, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3100 - accuracy: 0.9583 - val_loss: 0.5499 - val_accuracy: 0.8472 - 210ms/epoch - 23ms/step
# Epoch 245/300
#
# Epoch 245: val_loss did not improve from 0.54993
# 9/9 - 0s - loss: 0.3739 - accuracy: 0.9028 - val_loss: 0.5892 - val_accuracy: 0.7917 - 194ms/epoch - 22ms/step
# Epoch 246/300
#
# Epoch 246: val_loss did not improve from 0.54993
# 9/9 - 0s - loss: 0.3136 - accuracy: 0.9514 - val_loss: 0.5817 - val_accuracy: 0.7917 - 197ms/epoch - 22ms/step
# Epoch 247/300
#
# Epoch 247: val_loss did not improve from 0.54993
# 9/9 - 0s - loss: 0.2991 - accuracy: 0.9375 - val_loss: 0.5572 - val_accuracy: 0.8194 - 198ms/epoch - 22ms/step
# Epoch 248/300
#
# Epoch 248: val_loss did not improve from 0.54993
# 9/9 - 0s - loss: 0.3522 - accuracy: 0.9097 - val_loss: 0.5622 - val_accuracy: 0.8194 - 197ms/epoch - 22ms/step
# Epoch 249/300
#
# Epoch 249: val_loss improved from 0.54993 to 0.54045, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3633 - accuracy: 0.8819 - val_loss: 0.5404 - val_accuracy: 0.8750 - 209ms/epoch - 23ms/step
# Epoch 250/300
#
# Epoch 250: val_loss did not improve from 0.54045
# 9/9 - 0s - loss: 0.2990 - accuracy: 0.9375 - val_loss: 0.5691 - val_accuracy: 0.8333 - 198ms/epoch - 22ms/step
# Epoch 251/300
#
# Epoch 251: val_loss did not improve from 0.54045
# 9/9 - 0s - loss: 0.3354 - accuracy: 0.9514 - val_loss: 0.5903 - val_accuracy: 0.8333 - 205ms/epoch - 23ms/step
# Epoch 252/300
#
# Epoch 252: val_loss did not improve from 0.54045
# 9/9 - 0s - loss: 0.3070 - accuracy: 0.9444 - val_loss: 0.5839 - val_accuracy: 0.8194 - 194ms/epoch - 22ms/step
# Epoch 253/300
#
# Epoch 253: val_loss did not improve from 0.54045
# 9/9 - 0s - loss: 0.2889 - accuracy: 0.9514 - val_loss: 0.5439 - val_accuracy: 0.8611 - 199ms/epoch - 22ms/step
# Epoch 254/300
#
# Epoch 254: val_loss did not improve from 0.54045
# 9/9 - 0s - loss: 0.2708 - accuracy: 0.9583 - val_loss: 0.5681 - val_accuracy: 0.8472 - 194ms/epoch - 22ms/step
# Epoch 255/300
#
# Epoch 255: val_loss did not improve from 0.54045
# 9/9 - 0s - loss: 0.3581 - accuracy: 0.9028 - val_loss: 0.5417 - val_accuracy: 0.8611 - 197ms/epoch - 22ms/step
# Epoch 256/300
#
# Epoch 256: val_loss did not improve from 0.54045
# 9/9 - 0s - loss: 0.3003 - accuracy: 0.9306 - val_loss: 0.5554 - val_accuracy: 0.8333 - 195ms/epoch - 22ms/step
# Epoch 257/300
#
# Epoch 257: val_loss did not improve from 0.54045
# 9/9 - 0s - loss: 0.2978 - accuracy: 0.9583 - val_loss: 0.6009 - val_accuracy: 0.8333 - 199ms/epoch - 22ms/step
# Epoch 258/300
#
# Epoch 258: val_loss did not improve from 0.54045
# 9/9 - 0s - loss: 0.2886 - accuracy: 0.9583 - val_loss: 0.5631 - val_accuracy: 0.8472 - 197ms/epoch - 22ms/step
# Epoch 259/300
#
# Epoch 259: val_loss did not improve from 0.54045
# 9/9 - 0s - loss: 0.3161 - accuracy: 0.9097 - val_loss: 0.6009 - val_accuracy: 0.8333 - 214ms/epoch - 24ms/step
# Epoch 260/300
#
# Epoch 260: val_loss did not improve from 0.54045
# 9/9 - 0s - loss: 0.3046 - accuracy: 0.9514 - val_loss: 0.5739 - val_accuracy: 0.8056 - 194ms/epoch - 22ms/step
# Epoch 261/300
#
# Epoch 261: val_loss improved from 0.54045 to 0.51312, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3076 - accuracy: 0.9306 - val_loss: 0.5131 - val_accuracy: 0.8611 - 210ms/epoch - 23ms/step
# Epoch 262/300
#
# Epoch 262: val_loss did not improve from 0.51312
# 9/9 - 0s - loss: 0.3310 - accuracy: 0.9375 - val_loss: 0.5231 - val_accuracy: 0.8472 - 198ms/epoch - 22ms/step
# Epoch 263/300
#
# Epoch 263: val_loss improved from 0.51312 to 0.50726, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.2814 - accuracy: 0.9514 - val_loss: 0.5073 - val_accuracy: 0.8611 - 208ms/epoch - 23ms/step
# Epoch 264/300
#
# Epoch 264: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.3123 - accuracy: 0.9306 - val_loss: 0.5821 - val_accuracy: 0.8056 - 195ms/epoch - 22ms/step
# Epoch 265/300
#
# Epoch 265: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.3247 - accuracy: 0.9375 - val_loss: 0.5695 - val_accuracy: 0.7917 - 199ms/epoch - 22ms/step
# Epoch 266/300
#
# Epoch 266: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2873 - accuracy: 0.9444 - val_loss: 0.5281 - val_accuracy: 0.8194 - 200ms/epoch - 22ms/step
# Epoch 267/300
#
# Epoch 267: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.3374 - accuracy: 0.9375 - val_loss: 0.6034 - val_accuracy: 0.7778 - 198ms/epoch - 22ms/step
# Epoch 268/300
#
# Epoch 268: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2826 - accuracy: 0.9653 - val_loss: 0.5478 - val_accuracy: 0.8333 - 192ms/epoch - 21ms/step
# Epoch 269/300
#
# Epoch 269: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.3077 - accuracy: 0.9306 - val_loss: 0.5175 - val_accuracy: 0.8333 - 198ms/epoch - 22ms/step
# Epoch 270/300
#
# Epoch 270: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2996 - accuracy: 0.9375 - val_loss: 0.5247 - val_accuracy: 0.8333 - 191ms/epoch - 21ms/step
# Epoch 271/300
#
# Epoch 271: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2643 - accuracy: 0.9653 - val_loss: 0.5677 - val_accuracy: 0.8472 - 196ms/epoch - 22ms/step
# Epoch 272/300
#
# Epoch 272: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2959 - accuracy: 0.9444 - val_loss: 0.5716 - val_accuracy: 0.8472 - 200ms/epoch - 22ms/step
# Epoch 273/300
#
# Epoch 273: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2704 - accuracy: 0.9653 - val_loss: 0.5765 - val_accuracy: 0.8472 - 196ms/epoch - 22ms/step
# Epoch 274/300
#
# Epoch 274: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2872 - accuracy: 0.9375 - val_loss: 0.6015 - val_accuracy: 0.8194 - 198ms/epoch - 22ms/step
# Epoch 275/300
#
# Epoch 275: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2688 - accuracy: 0.9583 - val_loss: 0.5639 - val_accuracy: 0.8472 - 201ms/epoch - 22ms/step
# Epoch 276/300
#
# Epoch 276: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2917 - accuracy: 0.9583 - val_loss: 0.5300 - val_accuracy: 0.8611 - 195ms/epoch - 22ms/step
# Epoch 277/300
#
# Epoch 277: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2464 - accuracy: 0.9722 - val_loss: 0.5814 - val_accuracy: 0.8056 - 194ms/epoch - 22ms/step
# Epoch 278/300
#
# Epoch 278: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2816 - accuracy: 0.9306 - val_loss: 0.5582 - val_accuracy: 0.8056 - 198ms/epoch - 22ms/step
# Epoch 279/300
#
# Epoch 279: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.3662 - accuracy: 0.8819 - val_loss: 0.5503 - val_accuracy: 0.8056 - 195ms/epoch - 22ms/step
# Epoch 280/300
#
# Epoch 280: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2722 - accuracy: 0.9583 - val_loss: 0.5592 - val_accuracy: 0.8056 - 192ms/epoch - 21ms/step
# Epoch 281/300
#
# Epoch 281: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2924 - accuracy: 0.9167 - val_loss: 0.5647 - val_accuracy: 0.8194 - 197ms/epoch - 22ms/step
# Epoch 282/300
#
# Epoch 282: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2696 - accuracy: 0.9583 - val_loss: 0.5088 - val_accuracy: 0.8889 - 198ms/epoch - 22ms/step
# Epoch 283/300
#
# Epoch 283: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2844 - accuracy: 0.9444 - val_loss: 0.5484 - val_accuracy: 0.8472 - 195ms/epoch - 22ms/step
# Epoch 284/300
#
# Epoch 284: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2947 - accuracy: 0.9236 - val_loss: 0.5214 - val_accuracy: 0.8611 - 193ms/epoch - 21ms/step
# Epoch 285/300
#
# Epoch 285: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2883 - accuracy: 0.9583 - val_loss: 0.5845 - val_accuracy: 0.8056 - 194ms/epoch - 22ms/step
# Epoch 286/300
#
# Epoch 286: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2600 - accuracy: 0.9583 - val_loss: 0.5764 - val_accuracy: 0.7639 - 196ms/epoch - 22ms/step
# Epoch 287/300
#
# Epoch 287: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.3517 - accuracy: 0.9097 - val_loss: 0.5771 - val_accuracy: 0.7917 - 196ms/epoch - 22ms/step
# Epoch 288/300
#
# Epoch 288: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.3090 - accuracy: 0.9236 - val_loss: 0.5486 - val_accuracy: 0.8472 - 211ms/epoch - 23ms/step
# Epoch 289/300
#
# Epoch 289: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2855 - accuracy: 0.9514 - val_loss: 0.5593 - val_accuracy: 0.8056 - 195ms/epoch - 22ms/step
# Epoch 290/300
#
# Epoch 290: val_loss did not improve from 0.50726
# 9/9 - 0s - loss: 0.2521 - accuracy: 0.9514 - val_loss: 0.5299 - val_accuracy: 0.8056 - 198ms/epoch - 22ms/step
# Epoch 291/300
#
# Epoch 291: val_loss improved from 0.50726 to 0.49056, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.3157 - accuracy: 0.9236 - val_loss: 0.4906 - val_accuracy: 0.8750 - 207ms/epoch - 23ms/step
# Epoch 292/300
#
# Epoch 292: val_loss improved from 0.49056 to 0.48858, saving model to /tmp/checkpoint.h5
# 9/9 - 0s - loss: 0.2574 - accuracy: 0.9236 - val_loss: 0.4886 - val_accuracy: 0.8472 - 215ms/epoch - 24ms/step
# Epoch 293/300
#
# Epoch 293: val_loss did not improve from 0.48858
# 9/9 - 0s - loss: 0.2577 - accuracy: 0.9514 - val_loss: 0.5303 - val_accuracy: 0.8056 - 204ms/epoch - 23ms/step
# Epoch 294/300
#
# Epoch 294: val_loss did not improve from 0.48858
# 9/9 - 0s - loss: 0.2803 - accuracy: 0.9375 - val_loss: 0.5155 - val_accuracy: 0.8333 - 193ms/epoch - 21ms/step
# Epoch 295/300
#
# Epoch 295: val_loss did not improve from 0.48858
# 9/9 - 0s - loss: 0.2706 - accuracy: 0.9444 - val_loss: 0.5420 - val_accuracy: 0.8056 - 197ms/epoch - 22ms/step
# Epoch 296/300
#
# Epoch 296: val_loss did not improve from 0.48858
# 9/9 - 0s - loss: 0.2627 - accuracy: 0.9583 - val_loss: 0.5399 - val_accuracy: 0.8056 - 193ms/epoch - 21ms/step
# Epoch 297/300
#
# Epoch 297: val_loss did not improve from 0.48858
# 9/9 - 0s - loss: 0.2964 - accuracy: 0.9167 - val_loss: 0.5373 - val_accuracy: 0.7778 - 194ms/epoch - 22ms/step
# Epoch 298/300
#
# Epoch 298: val_loss did not improve from 0.48858
# 9/9 - 0s - loss: 0.2722 - accuracy: 0.9375 - val_loss: 0.5324 - val_accuracy: 0.7917 - 201ms/epoch - 22ms/step
# Epoch 299/300
#
# Epoch 299: val_loss did not improve from 0.48858
# 9/9 - 0s - loss: 0.2768 - accuracy: 0.9236 - val_loss: 0.5910 - val_accuracy: 0.7917 - 194ms/epoch - 22ms/step
# Epoch 300/300
#
# Epoch 300: val_loss did not improve from 0.48858
# 9/9 - 0s - loss: 0.2994 - accuracy: 0.9306 - val_loss: 0.5865 - val_accuracy: 0.8056 - 198ms/epoch - 22ms/step
# 3/3 [==============================] - 0s 5ms/step
# Classification accuracy: 0.902778
# Classification accuracy: 0.944444
# 0
